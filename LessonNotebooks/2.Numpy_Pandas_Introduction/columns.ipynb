# %%
import os
import pandas as pd
import numpy as np

# %% [markdown]
# ##### ADD NEW COLUMN (AGAIN)

# %% [markdown]
# ###### ASSIGN

# %%
os.getcwd()
csv_path = os.path.join(os.getcwd(), "..", "..", "data", "StudentsPerformance.csv")

df_exams = pd.read_csv(csv_path)

# %%
score1 = np.random.randint(0, 100, size=1000)
score2 = np.random.randint(0, 100, size=1000)
type(score1)
# Out:
# numpy.ndarray

# %%
series1 = pd.Series(score1, index=np.arange(0,1000))
series2 = pd.Series(score2, index=np.arange(0,1000))
type(series1)
# Out:
# pandas.core.series.Series

# %%
series1
# Out:
# 0      78
# 1      51
# 2      68
# 3      29
# 4      67
#        ..
# 995    39
# 996    17
# 997    49
# 998    74
# 999    62
# Length: 1000, dtype: int32

# %%
# It creates a copy
df_exams.assign(NewColumn_Score1=score1)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# ###### INSERT

# %%
# It doesn't create a copy, it changes directly the original
df_exams.insert(1, "test", series2)
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    60        group B           bachelor's degree      standard
# 1    female    24        group C                some college      standard
# 2    female    53        group B             master's degree      standard
# 3      male    23        group A          associate's degree  free/reduced
# 4      male    14        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    97        group E             master's degree      standard
# 996    male    44        group C                 high school  free/reduced
# 997  female    89        group C                 high school  free/reduced
# 998  female    49        group D                some college      standard
# 999  female    53        group D                some college  free/reduced
#
# ...

# %% [markdown]
# ##### RENAME COLUMNS AND INDEX

# %%
df_exams.rename(columns={"gender":"Gender"})
# Out:
#      Gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df_exams.rename(columns={"gender":"Gender",
                         "math score":"Math"}, inplace=True)

# %%
df_exams
# Out:
#      Gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  Math  reading score  writing score
# 0                      none    72             72             74
# ...

# %% [markdown]
# ###### INDEX

# %%
df_exams.rename(index={0:"A", 1:"B"})
# Out:
#      Gender race/ethnicity parental level of education         lunch  \
# A    female        group B           bachelor's degree      standard
# B    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  Math  reading score  writing score
# A                      none    72             72             74
# ...

# %%
new_df = df_exams.rename(index={0:"A", 1:"B"}).head(2)

# %%
new_df
# Out:
#    Gender race/ethnicity parental level of education     lunch  \
# A  female        group B           bachelor's degree  standard
# B  female        group C                some college  standard
#
#   test preparation course  Math  reading score  writing score
# A                    none    72             72             74
# B               completed    69             90             88

# %%
import sys
print(sys.path)
# Out:
# ['c:\\anaconda3\\envs\\python_DataScience\\python313.zip', 'c:\\anaconda3\\envs\\python_DataScience\\DLLs', 'c:\\anaconda3\\envs\\python_DataScience\\Lib', 'c:\\anaconda3\\envs\\python_DataScience', '', 'c:\\anaconda3\\envs\\python_DataScience\\Lib\\site-packages', 'C:\\Users\\Giacomo Da Re\\git\\Python_DataScience\\modules', 'c:\\anaconda3\\envs\\python_DataScience\\Lib\\site-packages\\win32', 'c:\\anaconda3\\envs\\python_DataScience\\Lib\\site-packages\\win32\\lib', 'c:\\anaconda3\\envs\\python_DataScience\\Lib\\site-packages\\Pythonwin']
