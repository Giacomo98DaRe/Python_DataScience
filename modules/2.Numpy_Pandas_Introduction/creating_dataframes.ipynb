# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##### 1. FROM AN ARRAY

# %%
# Create an array
first_data_example = np.array([[1, 2], [2, 4]])
first_data_example
# Out:
# array([[1, 2],
#        [2, 4]])

# %%
# Common name for a DataFrame: df

first_dataframe = pd.DataFrame(first_data_example, index=["lol", "lel"], columns=["col1", "col2"])
first_dataframe
# Out:
#      col1  col2
# lol     1     2
# lel     2     4

# %% [markdown]
# ##### FROM A LIST

# %%
# Create an array
example_list = [[1, 2], [2, 4]]
example_list
# Out:
# [[1, 2], [2, 4]]

# %%
second_df = pd.DataFrame(example_list)
second_df
# Out:
#    0  1
# 0  1  2
# 1  2  4

# %% [markdown]
# ##### 2. FROM A DICTIONARY

# %%
maldini_keys = ["age", "colour", "sex"]
maldini_values = ["56", "red and black", "yes"]

# %%
maldini_dict = {"keys":maldini_keys, "values": maldini_values}
maldini_dict
# Out:
# {'keys': ['age', 'colour', 'sex'], 'values': ['56', 'red and black', 'yes']}

# %%
df = pd.DataFrame({"keys":maldini_keys, "values": maldini_values})
df
# Out:
#      keys         values
# 0     age             56
# 1  colour  red and black
# 2     sex            yes

# %% [markdown]
# ##### 3. FROM CSV

# %%
import os

os.getcwd()
csv_path = os.path.join(os.getcwd(), "..", "data", "StudentsPerformance.csv")

# %%
csv_path
# Out:
# 'c:\\Users\\Giacomo Da Re\\git\\Python_DataScience\\script\\Numpy_Pandas_Introduction\\scripts\\..\\data\\StudentsPerformance.csv'

# %%
exams = pd.read_csv(csv_path)

# %%
exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...
