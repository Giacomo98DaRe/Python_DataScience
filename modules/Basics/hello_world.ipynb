# %%
print("Hello world")
# Out:
# Hello world

# %%
"Hello world"
# Out:
# 'Hello world'

# %%
1 + 2
# Out:
# 3

# %%
type(1)
# Out:
# int

# %%
type("lol")
# Out:
# str

# %%
"hello world".title()
# Out:
# 'Hello World'

# %%
"lol".count("l")
# Out:
# 2

# %%
"lol".replace("o", "e")
# Out:
# 'lel'
