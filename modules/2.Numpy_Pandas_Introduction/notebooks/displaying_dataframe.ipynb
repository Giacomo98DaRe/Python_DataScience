# %%
import os
import pandas as pd
import numpy as np

# %%
os.getcwd()
csv_path = os.path.join(os.getcwd(), "..", "..","..","data", "StudentsPerformance.csv")

df_exams = pd.read_csv(csv_path)
# Out:
# c:\Users\Giacomo Da Re\git\Python_DataScience\modules\2.Numpy_Pandas_Introduction\notebooks

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ##### 1. HEAD -> First Five

# %%
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df_exams.head(19)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %% [markdown]
# ##### 2. TAIL -> Last Five

# %%
df_exams.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df_exams.tail(12)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 988  female        group A            some high school  free/reduced
# 989  female        group D                some college  free/reduced
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ##### SHAPE ATTRIBUTES

# %%
df_exams.shape
# Out:
# (1000, 8)

# %%
df_exams.shape[0]
# Out:
# 1000

# %%
df_exams.shape[1]
# Out:
# 8

# %% [markdown]
# ###### OPTIONS

# %%
pd.set_option("display.max_rows", 1000)
df_exams

# %% [markdown]
# ##### 3. SELECTING ONE COLUMN

# %% [markdown]
# ###### 3.1 FIRST METHOD

# %%
df_exams["gender"]
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
type(df_exams["gender"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ###### SERIES

# %%
gender = df_exams["gender"]
gender.head()
gender.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %% [markdown]
# ###### 3.2 SECOND METHOD

# %%
df_exams.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
df_exams.math score 
# Of course that doesn't work

# %% [markdown]
# ##### 4. SELECTING TWO COLUMNS

# %%
df_exams[["gender", "math score"]]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
df_exams[["math score", "gender"]]
# Out:
#      math score  gender
# 0            72  female
# 1            69  female
# 2            90  female
# 3            47    male
# 4            76    male
# ..          ...     ...
# 995          88  female
# 996          62    male
# 997          59  female
# 998          68  female
# 999          77  female
#
# [1000 rows x 2 columns]

# %%
type(df_exams[["gender", "math score"]])
# Out:
# pandas.core.frame.DataFrame

# %%
three_columns = df_exams[["gender", "math score", "lunch"]]
three_columns
# Out:
#      gender  math score         lunch
# 0    female          72      standard
# 1    female          69      standard
# 2    female          90      standard
# 3      male          47  free/reduced
# 4      male          76      standard
# ..      ...         ...           ...
# 995  female          88      standard
# 996    male          62  free/reduced
# 997  female          59  free/reduced
# 998  female          68      standard
# 999  female          77  free/reduced
#
# [1000 rows x 3 columns]

# %% [markdown]
# ##### 5. LOC / ILOC

# %%
df_exams.loc[:, ["gender", "math score"]]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
df_exams.iloc[:, [0, 1]]
# Out:
#      gender race/ethnicity
# 0    female        group B
# 1    female        group C
# 2    female        group B
# 3      male        group A
# 4      male        group C
# ..      ...            ...
# 995  female        group E
# 996    male        group C
# 997  female        group C
# 998  female        group D
# 999  female        group D
#
# [1000 rows x 2 columns]

# %%
# Posso con loc e iloc selezionare le colonne in base al nome o alla posizione in maniera esplicita

# %% [markdown]
# ###### EXERCISE:

# %% [markdown]
# ##### ADDING A NEW COLUMN

# %% [markdown]
# ###### 1.1 WITH A SCALAR VALUE

# %%
df_exams["language score"] = 70
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# ###### 1.2 WITH NUMPY

# %%
language_score = np.arange(0, 1000)

# %%
type(language_score)
len(language_score)
# Out:
# 1000

# %%
new_df_exams = df_exams.iloc[: , :8]
type(new_df_exams)
new_df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
new_df_exams["new_language_score"] = language_score

# %%
new_df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
language_score_1_100 = np.random.randint(1, 100, size=1000)
language_score_1_100
# Out:
# array([53, 75, 88,  8, 74, 31, 41, 65, 24, 77, 18, 61, 93, 92, 87, 96, 17,
#        54, 82, 12, 95,  1, 78, 24, 58, 11, 96, 69, 80, 42, 16, 83, 46, 70,
#        55, 97,  6, 73, 19, 21, 14, 72, 27, 87, 13, 84, 73, 81, 42, 15, 56,
#        65, 24, 10, 13, 46, 44, 64, 80, 98, 50, 47, 43, 69, 84, 78, 23, 67,
#        12, 14, 14, 58, 25, 23,  9, 91,  2, 70, 19, 79,  8, 30, 90, 57, 96,
#        76, 89, 87, 81, 83, 24, 96, 25, 29, 41, 38, 69, 65, 44, 88, 25, 81,
#        87, 59, 64, 21, 44, 25, 50, 73, 37, 80, 64, 79, 37, 16, 20, 94, 33,
#        39,  5, 63, 87,  5, 55, 22, 72, 40,  7, 66, 64, 64, 56, 63, 58, 72,
#        99, 62,  6, 49, 80, 20, 47, 67, 71, 52, 76, 53, 17, 63, 94, 86, 20,
#        85, 61, 83, 19, 97, 60, 48,  8, 59, 70, 58, 81, 91, 47, 49, 59,  2,
#        48, 92, 61, 52, 81, 20, 45, 37, 86,  5, 33, 82, 19, 58, 81, 80, 13,
#        50,  5, 15, 46, 70, 76, 48, 43, 33, 96, 74, 77, 28, 63, 23, 97, 10,
# ...

# %%
min(language_score_1_100)
# Out:
# np.int32(1)

# %%
max(language_score_1_100)
# Out:
# np.int32(99)

# %%
new_df_exams["new_language_score"] = language_score_1_100
new_df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
float_list = np.random.uniform(0, 100, 1000)
float_list
# Out:
# array([5.03013395e+01, 2.89146849e+00, 3.35624552e+01, 7.84346830e+01,
#        8.01361351e+00, 6.97917152e+01, 6.44770748e+01, 4.49920029e+01,
#        1.29582124e+01, 6.77248753e+01, 4.40763037e+01, 9.46020375e+01,
#        4.56952774e+01, 4.85053576e+01, 3.56235271e+00, 6.65204736e+01,
#        6.90286363e+01, 3.57334156e+01, 9.60258720e+01, 9.84250389e+01,
#        9.54419761e+01, 3.59000505e+01, 6.88005282e+01, 5.17872884e+01,
#        9.93260930e+01, 1.53200530e+01, 6.01320600e+01, 9.48843689e+01,
#        9.73386341e+01, 3.88677125e+01, 4.28520798e+01, 4.69671857e+01,
#        7.62906374e+01, 8.91927258e+01, 2.03063641e+01, 4.16557082e+01,
#        1.46832968e+00, 7.75703617e+01, 6.65494754e+01, 3.64572762e+01,
#        9.61042570e+01, 8.59823212e+01, 6.10074617e+01, 3.47937526e+01,
#        6.30923910e+01, 2.06595702e+01, 3.16965009e+01, 2.60034323e+01,
#        7.07857613e+01, 9.24952339e+01, 1.57906392e+01, 2.19209083e+01,
# ...

# %%
min(float_list)
# Out:
# np.float64(0.05281212222140175)

# %%
max(float_list)
# Out:
# np.float64(99.9896499109567)
