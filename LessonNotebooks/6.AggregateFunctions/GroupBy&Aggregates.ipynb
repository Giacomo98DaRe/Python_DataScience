# %%
import pandas as pd
import numpy as np
from utilities.reader_tools import GenericDatasetReader

df_carSales = GenericDatasetReader.DataframeFromCSV("Car_sales.csv")
df_carSales.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0        2.639           13.2             28.0      2/2/2012
# 1        3.517           17.2             25.0      6/3/2011
# 2        3.470           17.2             26.0      1/4/2012
# 3        3.850           18.0             22.0     3/10/2011
# 4        2.998           16.4             27.0     10/8/2011
#
#    Power_perf_factor
# 0          58.280150
# 1          91.370778
# 2                NaN
# 3          91.389779
# 4          62.777639

# %%
df_carSales["Vehicle_type"].value_counts()
# Out:
# Vehicle_type
# Passenger    116
# Car           41
# Name: count, dtype: int64

# %%
df_carSales = df_carSales[["Manufacturer", "Sales_in_thousands", "Vehicle_type", "Price_in_thousands", "Engine_size", "Horsepower", "Fuel_capacity"]]
df_carSales
# Out:
#     Manufacturer  Sales_in_thousands Vehicle_type  Price_in_thousands  \
# 0          Acura              16.919    Passenger               21.50
# 1          Acura              39.384    Passenger               28.40
# 2          Acura              14.114    Passenger                 NaN
# 3          Acura               8.588    Passenger               42.00
# 4           Audi              20.397    Passenger               23.99
# ..           ...                 ...          ...                 ...
# 152        Volvo               3.545    Passenger               24.40
# 153        Volvo              15.245    Passenger               27.50
# 154        Volvo              17.531    Passenger               28.80
# 155        Volvo               3.493    Passenger               45.50
# 156        Volvo              18.969    Passenger               36.00
#
#      Engine_size  Horsepower  Fuel_capacity
# 0            1.8       140.0           13.2
# 1            3.2       225.0           17.2
# 2            3.2       225.0           17.2
# 3            3.5       210.0           18.0
# 4            1.8       150.0           16.4
# ..           ...         ...            ...
# 152          1.9       160.0           15.8
# 153          2.4       168.0           17.9
# 154          2.4       168.0           17.9
# 155          2.3       236.0           18.5
# 156          2.9       201.0           21.1
#
# [157 rows x 7 columns]

# %%
df_carSales.nunique()
# Out:
# Manufacturer           30
# Sales_in_thousands    157
# Vehicle_type            2
# Price_in_thousands    152
# Engine_size            31
# Horsepower             66
# Fuel_capacity          55
# dtype: int64

# %% [markdown]
# ##### AGGREGATIONS -> agg()

# %%
# Sum of columns
df_carSales.agg("sum")
# Out:
# Manufacturer          AcuraAcuraAcuraAcuraAudiAudiAudiBMWBMWBMWBuick...
# Sales_in_thousands                                             8320.698
# Vehicle_type          PassengerPassengerPassengerPassengerPassengerP...
# Price_in_thousands                                             4245.567
# Engine_size                                                       477.5
# Horsepower                                                      29008.0
# Fuel_capacity                                                    2800.5
# dtype: object

# %%
# It doesn't work with string values. Select only numerical one
df_carSales.select_dtypes(include=np.number).agg("mean")
# Out:
# Sales_in_thousands     52.998076
# Price_in_thousands     27.390755
# Engine_size             3.060897
# Horsepower            185.948718
# Fuel_capacity          17.951923
# dtype: float64

# %%
# I can include any function in the list as arguments
df_carSales.select_dtypes(include=np.number).agg(["mean", "count"])
# Out:
#        Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  \
# mean            52.998076           27.390755     3.060897  185.948718
# count          157.000000          155.000000   156.000000  156.000000
#
#        Fuel_capacity
# mean       17.951923
# count     156.000000

# %%
# Different aggregations over columns
df_carSales.agg({"Sales_in_thousands":["sum", "mean"],
                "Price_in_thousands":["sum", "max"]})
# Out:
#       Sales_in_thousands  Price_in_thousands
# sum          8320.698000            4245.567
# mean           52.998076                 NaN
# max                  NaN              85.500

# %%
# In this case no sense.
df_carSales[["Sales_in_thousands", "Price_in_thousands"]].agg("sum", axis=1)
# Out:
# 0      38.419
# 1      67.784
# 2      14.114
# 3      50.588
# 4      44.387
#         ...
# 152    27.945
# 153    42.745
# 154    46.331
# 155    48.993
# 156    54.969
# Length: 157, dtype: float64

# %%
# Different from the previous approach, the Nan value here is present. If you use agg it will count Nan as 0
df_carSales["Sales_in_thousands"] + df_carSales["Price_in_thousands"]
# Out:
# 0      38.419
# 1      67.784
# 2         NaN
# 3      50.588
# 4      44.387
#         ...
# 152    27.945
# 153    42.745
# 154    46.331
# 155    48.993
# 156    54.969
# Length: 157, dtype: float64

# %%
# Rename indexes
df_carSales.agg(sum = ("Sales_in_thousands", "sum"),
                 y = ("Price_in_thousands", "sum"))
# Out:
#      Sales_in_thousands  Price_in_thousands
# sum            8320.698                 NaN
# y                   NaN            4245.567

# %% [markdown]
# ##### SPLIT-APPLY-COMBINE STRATEGY -> BEHIND GROUP BY METHOD

# %%
df_carSales["Vehicle_type"].value_counts()
# Out:
# Vehicle_type
# Passenger    116
# Car           41
# Name: count, dtype: int64

# %%
# Split data
passenger_filter = df_carSales["Vehicle_type"] == "Passenger"
car_filter = df_carSales["Vehicle_type"] == "Car"

# %%
# Apply an operation
passenger_sales_mean = df_carSales[passenger_filter]["Sales_in_thousands"].mean()
car_sales_mean = df_carSales[car_filter]["Sales_in_thousands"].mean()

# %%
# Combine results. I create a new DF with the data matched correctly
pd.DataFrame({"Vehicle_type":["Car", "Passenger"],
              "Sales_in_thousands": [car_sales_mean, passenger_sales_mean]})
# Out:
#   Vehicle_type  Sales_in_thousands
# 0          Car           80.622293
# 1    Passenger           43.234345

# %% [markdown]
# ##### GROUP BY
#
# If you apply an agg function on a df that contains string values, you will get an error.
# If you group by per a certain string value and then aggregate, the other string values present in the df don't have to be considered.
#
# To afford the problem:
#
# 1. Set numeric only parameter to true -> you don't have the full control of what is going on
#
# 2. Other solution:
#
# import numpy as np
#
# Step 1: Select only numeric columns and the grouping column
# We use select_dtypes to grab all float/int columns automatically
# numeric_cols = df_carSales.select_dtypes(include=[np.number]).columns.tolist()
# df_subset = df_carSales[["Vehicle_type"] + numeric_cols]
#
# Step 2: Perform the groupby
# Now there is no risk of TypeError as all other columns are numeric
# df_subset.groupby("Vehicle_type").mean()

# %%
df_carSales.groupby("Vehicle_type").mean(numeric_only=True)

# I can also add as_index=False if I want default indexing
# Out:
#               Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  \
# Vehicle_type
# Car                    80.622293           26.319975     3.520000  186.400000
# Passenger              43.234345           27.763200     2.902586  185.793103
#
#               Fuel_capacity
# Vehicle_type
# Car               21.895000
# Passenger         16.592241

# %%
groupedby_Manuf = df_carSales.groupby("Manufacturer")

# %%
# Type is not DataFrame, but dfgroupby (so with other characteristics)
type(groupedby_Manuf)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
groupedby_Manuf.groups.keys()
# Out:
# dict_keys(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet', 'Chrysler', 'Dodge', 'Ford', 'Honda', 'Hyundai', 'Infiniti', 'Jaguar', 'Jeep', 'Lexus', 'Lincoln', 'Mercedes-B', 'Mercury', 'Mitsubishi', 'Nissan', 'Oldsmobile', 'Plymouth', 'Pontiac', 'Porsche', 'Saab', 'Saturn', 'Subaru', 'Toyota', 'Volkswagen', 'Volvo'])

# %%
groupedby_Manuf.get_group("Ford")
# Out:
#    Manufacturer  Sales_in_thousands Vehicle_type  Price_in_thousands  \
# 46         Ford              70.227    Passenger              12.070
# 47         Ford             113.369    Passenger              21.560
# 48         Ford              35.068    Passenger              17.035
# 49         Ford             245.815    Passenger              17.885
# 50         Ford             175.670    Passenger              12.315
# 51         Ford              63.403    Passenger              22.195
# 52         Ford             276.747          Car              31.930
# 53         Ford             155.787          Car              21.410
# 54         Ford             125.338          Car              36.135
# 55         Ford             220.650          Car              12.050
# 56         Ford             540.561          Car              26.935
#
#     Engine_size  Horsepower  Fuel_capacity
# 46          2.0       110.0           12.7
# 47          3.8       190.0           15.7
# 48          2.5       170.0           15.0
# 49          3.0       155.0           16.0
# 50          2.0       107.0           13.2
# 51          4.6       200.0           19.0
# 52          4.0       210.0           21.0
# 53          3.0       150.0           26.0
# 54          4.6       240.0           26.0
# 55          2.5       119.0           20.0
# 56          4.6       220.0           25.1

# %%
groupedby_Manuf.mean(numeric_only=True)
# Out:
#               Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  \
# Manufacturer
# Acura                  19.751250           30.633333     2.925000  200.000000
# Audi                   13.519000           39.980000     2.933333  220.000000
# BMW                    15.501667           33.096667     2.700000  185.333333
# Buick                  60.504750           26.781250     3.625000  206.250000
# Cadillac               22.435600           40.254000     4.500000  256.000000
# Chevrolet              61.596111           20.022778     3.055556  171.111111
# Chrysler               28.817286           23.430833     2.783333  194.833333
# Dodge                  82.740818           24.213636     3.709091  199.545455
# Ford                  183.875909           21.047273     3.327273  170.090909
# Honda                 118.534800           20.277000     2.520000  160.400000
# Hyundai                45.775333           12.165667     1.966667  126.666667
# Infiniti               23.713000           29.465000     3.000000  227.000000
# Jaguar                 15.467000           42.800000     3.000000  240.000000
# Jeep                   97.717667           20.991667     3.500000  168.333333
# Lexus                  17.807167           44.055000     3.616667  245.833333
# Lincoln                28.544667           41.690000     4.866667  263.333333
# Mercedes-B             13.013889           52.916667     3.422222  232.222222
# Mercury                39.666500           20.748333     3.150000  163.833333
# Mitsubishi             25.842143           22.167429     2.800000  165.142857
# Nissan                 57.090714           22.360714     2.914286  169.000000
# Oldsmobile             29.831500           25.622833     3.450000  190.000000
# Plymouth               16.000250           22.642500     2.475000  166.750000
# Pontiac                61.755667           22.949167     3.433333  185.000000
# Porsche                 4.042667           62.473333     3.166667  272.333333
# Saab                   10.653000           29.610000     2.150000  177.500000
# Saturn                 33.770000           14.271000     2.020000  119.600000
# Subaru                 40.067500           21.395000     2.500000  165.000000
# Toyota                 82.245000           21.982889     2.622222  160.666667
# Volkswagen             34.868667           17.698333     1.966667  120.833333
# Volvo                  12.623333           30.933333     2.300000  182.166667
#
#               Fuel_capacity
# Manufacturer
# Acura             16.400000
# Audi              19.533333
# BMW               17.233333
# Buick             17.750000
# Cadillac          20.800000
# Chevrolet         15.477778
# Chrysler          16.483333
# Dodge             21.581818
# Ford              19.063636
# Honda             17.080000
# Hyundai           14.533333
# Infiniti          18.500000
# Jaguar            18.400000
# Jeep              19.833333
# Lexus             20.533333
# Lincoln           23.000000
# Mercedes-B        18.922222
# Mercury           17.833333
# Mitsubishi        18.285714
# Nissan            18.200000
# Oldsmobile        18.200000
# Plymouth          15.125000
# Pontiac           17.916667
# Porsche           17.000000
# Saab              17.700000
# Saturn            12.500000
# Subaru            16.400000
# Toyota            17.766667
# Volkswagen        14.700000
# Volvo             17.833333

# %%
groupedby_Manuf.sum(numeric_only=True)
# Out:
#               Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  \
# Manufacturer
# Acura                     79.005              91.900         11.7       800.0
# Audi                      40.557             119.940          8.8       660.0
# BMW                       46.505              99.290          8.1       556.0
# Buick                    242.019             107.125         14.5       825.0
# Cadillac                 112.178             201.270         22.5      1280.0
# Chevrolet                554.365             180.205         27.5      1540.0
# Chrysler                 201.721             140.585         16.7      1169.0
# Dodge                    910.149             266.350         40.8      2195.0
# Ford                    2022.635             231.520         36.6      1871.0
# Honda                    592.674             101.385         12.6       802.0
# Hyundai                  137.326              36.497          5.9       380.0
# Infiniti                  23.713              29.465          3.0       227.0
# Jaguar                    15.467              42.800          3.0       240.0
# Jeep                     293.153              62.975         10.5       505.0
# Lexus                    106.843             264.330         21.7      1475.0
# Lincoln                   85.634             125.070         14.6       790.0
# Mercedes-B               117.125             476.250         30.8      2090.0
# Mercury                  237.999             124.490         18.9       983.0
# Mitsubishi               180.895             155.172         19.6      1156.0
# Nissan                   399.635             156.525         20.4      1183.0
# Oldsmobile               178.989             153.737         20.7      1140.0
# Plymouth                  64.001              90.570          9.9       667.0
# Pontiac                  370.534             137.695         20.6      1110.0
# Porsche                   12.128             187.420          9.5       817.0
# Saab                      21.306              59.220          4.3       355.0
# Saturn                   168.850              71.355         10.1       598.0
# Subaru                    80.135              42.790          5.0       330.0
# Toyota                   740.205             197.846         23.6      1446.0
# Volkswagen               209.212             106.190         11.8       725.0
# Volvo                     75.740             185.600         13.8      1093.0
#
#               Fuel_capacity
# Manufacturer
# Acura                  65.6
# Audi                   58.6
# BMW                    51.7
# Buick                  71.0
# Cadillac              104.0
# Chevrolet             139.3
# Chrysler               98.9
# Dodge                 237.4
# Ford                  209.7
# Honda                  85.4
# Hyundai                43.6
# Infiniti               18.5
# Jaguar                 18.4
# Jeep                   59.5
# Lexus                 123.2
# Lincoln                69.0
# Mercedes-B            170.3
# Mercury               107.0
# Mitsubishi            128.0
# Nissan                127.4
# Oldsmobile            109.2
# Plymouth               60.5
# Pontiac               107.5
# Porsche                51.0
# Saab                   35.4
# Saturn                 62.5
# Subaru                 32.8
# Toyota                159.9
# Volkswagen             88.2
# Volvo                 107.0

# %%
df_carSales.groupby("Vehicle_type").count()

# Some columns are NaN
# Out:
#               Manufacturer  Sales_in_thousands  Price_in_thousands  \
# Vehicle_type
# Car                     41                  41                  40
# Passenger              116                 116                 115
#
#               Engine_size  Horsepower  Fuel_capacity
# Vehicle_type
# Car                    40          40             40
# Passenger             116         116            116

# %%
df_carSales.isnull().sum()
# Out:
# Manufacturer          0
# Sales_in_thousands    0
# Vehicle_type          0
# Price_in_thousands    2
# Engine_size           1
# Horsepower            1
# Fuel_capacity         1
# dtype: int64

# %%
# I also count the null value
df_carSales.groupby("Engine_size", dropna=False).count()
# Out:
#              Manufacturer  Sales_in_thousands  Vehicle_type  \
# Engine_size
# 1.0                     1                   1             1
# 1.5                     1                   1             1
# 1.6                     1                   1             1
# 1.8                     8                   8             8
# 1.9                     5                   5             5
# 2.0                    17                  17            17
# 2.2                     4                   4             4
# 2.3                     6                   6             6
# 2.4                    11                  11            11
# 2.5                    11                  11            11
# 2.7                     4                   4             4
# 2.8                     3                   3             3
# 2.9                     1                   1             1
# 3.0                    14                  14            14
# 3.1                     4                   4             4
# 3.2                     6                   6             6
# 3.3                     5                   5             5
# 3.4                     7                   7             7
# 3.5                     8                   8             8
# 3.8                     8                   8             8
# 3.9                     2                   2             2
# 4.0                     7                   7             7
# 4.2                     1                   1             1
# 4.3                     2                   2             2
# 4.6                     9                   9             9
# 4.7                     2                   2             2
# 5.0                     2                   2             2
# 5.2                     2                   2             2
# 5.4                     1                   1             1
# 5.7                     2                   2             2
# 8.0                     1                   1             1
# NaN                     1                   1             1
#
#              Price_in_thousands  Horsepower  Fuel_capacity
# Engine_size
# 1.0                           1           1              1
# 1.5                           1           1              1
# 1.6                           1           1              1
# 1.8                           8           8              8
# 1.9                           5           5              5
# 2.0                          17          17             17
# 2.2                           4           4              4
# 2.3                           6           6              6
# 2.4                          11          11             11
# 2.5                          11          11             11
# 2.7                           4           4              4
# 2.8                           3           3              3
# 2.9                           1           1              1
# 3.0                          14          14             14
# 3.1                           4           4              4
# 3.2                           5           6              6
# 3.3                           5           5              5
# 3.4                           7           7              7
# 3.5                           8           8              8
# 3.8                           8           8              8
# 3.9                           2           2              2
# 4.0                           7           7              7
# 4.2                           1           1              1
# 4.3                           2           2              2
# 4.6                           9           9              9
# 4.7                           2           2              2
# 5.0                           2           2              2
# 5.2                           2           2              2
# 5.4                           1           1              1
# 5.7                           2           2              2
# 8.0                           1           1              1
# NaN                           0           0              0

# %% [markdown]
# ##### GROUPBY AND AGG()

# %%
# Find min and max value on each column

df_carSales.groupby("Vehicle_type").agg(["min", "max"])
# Out:
#              Manufacturer         Sales_in_thousands           \
#                       min     max                min      max
# Vehicle_type
# Car              Cadillac  Toyota              9.126  540.561
# Passenger           Acura   Volvo              0.110  247.994
#
#              Price_in_thousands         Engine_size      Horsepower         \
#                             min     max         min  max        min    max
# Vehicle_type
# Car                      11.528  60.105         2.0  5.7      119.0  300.0
# Passenger                 9.235  85.500         1.0  8.0       55.0  450.0
#
#              Fuel_capacity
#                        min   max
# Vehicle_type
# Car                   15.1  32.0
# Passenger             10.3  23.7

# %%
df_carSales.groupby("Vehicle_type").agg(min_engine = ("Engine_size", "min"),
                                        max_horse=("Horsepower", "max"))
# Out:
#               min_engine  max_horse
# Vehicle_type
# Car                  2.0      300.0
# Passenger            1.0      450.0

# %% [markdown]
# ##### What's behind the next instruction?
#
# df_carSales.groupby("Manufacturer").sum()["Sales_in_thousands"]
# df_carSales.groupby("Manufacturer").mean()["Price_in_thousands"]
#
# Of course, the next instruction version is more scalable and powerful

# %%
# Sum of sales and mean of price for manufacterer
df_carSales.groupby("Manufacturer").agg(sumSales = ("Sales_in_thousands", "sum"),
                                        meanPrice=("Price_in_thousands", "mean"))
# Out:
#               sumSales  meanPrice
# Manufacturer
# Acura           79.005  30.633333
# Audi            40.557  39.980000
# BMW             46.505  33.096667
# Buick          242.019  26.781250
# Cadillac       112.178  40.254000
# Chevrolet      554.365  20.022778
# Chrysler       201.721  23.430833
# Dodge          910.149  24.213636
# Ford          2022.635  21.047273
# Honda          592.674  20.277000
# Hyundai        137.326  12.165667
# Infiniti        23.713  29.465000
# Jaguar          15.467  42.800000
# Jeep           293.153  20.991667
# Lexus          106.843  44.055000
# Lincoln         85.634  41.690000
# Mercedes-B     117.125  52.916667
# Mercury        237.999  20.748333
# Mitsubishi     180.895  22.167429
# Nissan         399.635  22.360714
# Oldsmobile     178.989  25.622833
# Plymouth        64.001  22.642500
# Pontiac        370.534  22.949167
# Porsche         12.128  62.473333
# Saab            21.306  29.610000
# Saturn         168.850  14.271000
# Subaru          80.135  21.395000
# Toyota         740.205  21.982889
# Volkswagen     209.212  17.698333
# Volvo           75.740  30.933333

# %% [markdown]
# ##### APPLY MY FUNCTION: LAMBDA

# %%
# Example: apply the real value (so multiply by 1000)

df_carSales.groupby("Manufacturer").sum().apply(lambda x:x*1000)[["Sales_in_thousands", "Price_in_thousands"]]
# Out:
#               Sales_in_thousands  Price_in_thousands
# Manufacturer
# Acura                    79005.0             91900.0
# Audi                     40557.0            119940.0
# BMW                      46505.0             99290.0
# Buick                   242019.0            107125.0
# Cadillac                112178.0            201270.0
# Chevrolet               554365.0            180205.0
# Chrysler                201721.0            140585.0
# Dodge                   910149.0            266350.0
# Ford                   2022635.0            231520.0
# Honda                   592674.0            101385.0
# Hyundai                 137326.0             36497.0
# Infiniti                 23713.0             29465.0
# Jaguar                   15467.0             42800.0
# Jeep                    293153.0             62975.0
# Lexus                   106843.0            264330.0
# Lincoln                  85634.0            125070.0
# Mercedes-B              117125.0            476250.0
# Mercury                 237999.0            124490.0
# Mitsubishi              180895.0            155172.0
# Nissan                  399635.0            156525.0
# Oldsmobile              178989.0            153737.0
# Plymouth                 64001.0             90570.0
# Pontiac                 370534.0            137695.0
# Porsche                  12128.0            187420.0
# Saab                     21306.0             59220.0
# Saturn                  168850.0             71355.0
# Subaru                   80135.0             42790.0
# Toyota                  740205.0            197846.0
# Volkswagen              209212.0            106190.0
# Volvo                    75740.0            185600.0

# %%
# Example: subtract the mean. Mean is calculated just on the numerical values, but the subtraction is made on all the columns (also the string and text ones). This behavior will cause problems in the future. Use transform instead

df_carSales.groupby("Manufacturer").apply(lambda x:x-x.mean(numeric_only=True)) #[["Sales_in_thousands", "Price_in_thousands"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 3
#       1 # Example: substract the mean
# ----> 3 df_carSales.groupby("Manufacturer").transform(lambda x:x-x.mean()) #[["Sales_in_thousands", "Price_in_thousands"]]
#
# File c:\anaconda3\envs\python_DataScience\Lib\site-packages\pandas\core\groupby\generic.py:1815, in DataFrameGroupBy.transform(self, func, engine, engine_kwargs, *args, **kwargs)
#    1812 @Substitution(klass="DataFrame", example=__examples_dataframe_doc)
#    1813 @Appender(_transform_template)
#    1814 def transform(self, func, *args, engine=None, engine_kwargs=None, **kwargs):
# -> 1815     return self._transform(
#    1816         func, *args, engine=engine, engine_kwargs=engine_kwargs, **kwargs
#    1817     )
#
# File c:\anaconda3\envs\python_DataScience\Lib\site-packages\pandas\core\groupby\groupby.py:2028, in GroupBy._transform(self, func, engine, engine_kwargs, *args, **kwargs)
#    2025     warn_alias_replacement(self, orig_func, func)
#    2027 if not isinstance(func, str):
# -> 2028     return self._transform_general(func, engine, engine_kwargs, *args, **kwargs)
#    2030 elif func not in base.transform_kernel_allowlist:
#    2031     msg = f"'{func}' is not a valid function name for transform(name)"
#
# File c:\anaconda3\envs\python_DataScience\Lib\site-packages\pandas\core\groupby\generic.py:1732, in DataFrameGroupBy._transform_general(self, func, engine, engine_kwargs, *args, **kwargs)
#    1730 object.__setattr__(group, "name", name)
#    1731 try:
# -> 1732     path, res = self._choose_path(fast_path, slow_path, group)
#    1733 except ValueError as err:
#    1734     # e.g. test_transform_with_non_scalar_group
#    1735     msg = "transform must return a scalar value for each group"
#
# File c:\anaconda3\envs\python_DataScience\Lib\site-packages\pandas\core\groupby\generic.py:1834, in DataFrameGroupBy._choose_path(self, fast_path, slow_path, group)
#    1832 def _choose_path(self, fast_path: Callable, slow_path: Callable, group: DataFrame):
#    1833     path = slow_path
# -> 1834     res = slow_path(group)
#    1836     if self.ngroups == 1:
#    1837         # no need to evaluate multiple paths when only
#    1838         # a single group exists
#    1839         return path, res
#
# File c:\anaconda3\envs\python_DataScience\Lib\site-packages\pandas\core\groupby\generic.py:1827, in DataFrameGroupBy._define_paths.<locals>.<lambda>(group)
#    1825 else:
#    1826     fast_path = lambda group: func(group, *args, **kwargs)
# -> 1827     slow_path = lambda group: group.apply(
#    1828         lambda x: func(x, *args, **kwargs), axis=self.axis
#    1829     )
#    1830 return fast_path, slow_path
#
# File c:\anaconda3\envs\python_DataScience\Lib\site-packages\pandas\core\frame.py:10401, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10387 from pandas.core.apply import frame_apply
#   10389 op = frame_apply(
#   10390     self,
#   10391     func=func,
#    (...)  10399     kwargs=kwargs,
#   10400 )
# > 10401 return op.apply().__finalize__(self, method="apply")
#
# File c:\anaconda3\envs\python_DataScience\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File c:\anaconda3\envs\python_DataScience\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File c:\anaconda3\envs\python_DataScience\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# File c:\anaconda3\envs\python_DataScience\Lib\site-packages\pandas\core\groupby\generic.py:1828, in DataFrameGroupBy._define_paths.<locals>.<lambda>.<locals>.<lambda>(x)
#    1825 else:
#    1826     fast_path = lambda group: func(group, *args, **kwargs)
#    1827     slow_path = lambda group: group.apply(
# -> 1828         lambda x: func(x, *args, **kwargs), axis=self.axis
#    1829     )
#    1830 return fast_path, slow_path
#
# Cell In[85], line 3, in <lambda>(x)
#       1 # Example: substract the mean
# ----> 3 df_carSales.groupby("Manufacturer").transform(lambda x:x-x.mean()) #[["Sales_in_thousands", "Price_in_thousands"]]
#
# File c:\anaconda3\envs\python_DataScience\Lib\site-packages\pandas\core\series.py:6570, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("mean", ndim=1))
#    6563 def mean(
#    6564     self,
#    (...)   6568     **kwargs,
#    6569 ):
# -> 6570     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\anaconda3\envs\python_DataScience\Lib\site-packages\pandas\core\generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)  12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
#   12486         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12487     )
#
# File c:\anaconda3\envs\python_DataScience\Lib\site-packages\pandas\core\generic.py:12442, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12438 nv.validate_func(name, (), kwargs)
#   12440 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12442 return self._reduce(
#   12443     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12444 )
#
# File c:\anaconda3\envs\python_DataScience\Lib\site-packages\pandas\core\series.py:6478, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6473     # GH#47500 - change to TypeError to match other methods
#    6474     raise TypeError(
#    6475         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6476         "with non-numeric dtypes."
#    6477     )
# -> 6478 return op(delegate, skipna=skipna, **kwds)
#
# File c:\anaconda3\envs\python_DataScience\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\anaconda3\envs\python_DataScience\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File c:\anaconda3\envs\python_DataScience\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#     723     count = cast(np.ndarray, count)
#
# File c:\anaconda3\envs\python_DataScience\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1698 elif not (is_float(x) or is_integer(x) or is_complex(x)):
#    1699     if isinstance(x, str):
#    1700         # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701         raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702     try:
#    1703         x = float(x)
#
# TypeError: Could not convert string 'PassengerPassengerPassengerPassenger' to numeric

# %%
# Note that the argument of groupby() is used as the index of the generated df
df_carSales.groupby("Manufacturer").mean(numeric_only=True)
# Out:
#               Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  \
# Manufacturer
# Acura                  19.751250           30.633333     2.925000  200.000000
# Audi                   13.519000           39.980000     2.933333  220.000000
# BMW                    15.501667           33.096667     2.700000  185.333333
# Buick                  60.504750           26.781250     3.625000  206.250000
# Cadillac               22.435600           40.254000     4.500000  256.000000
# Chevrolet              61.596111           20.022778     3.055556  171.111111
# Chrysler               28.817286           23.430833     2.783333  194.833333
# Dodge                  82.740818           24.213636     3.709091  199.545455
# Ford                  183.875909           21.047273     3.327273  170.090909
# Honda                 118.534800           20.277000     2.520000  160.400000
# Hyundai                45.775333           12.165667     1.966667  126.666667
# Infiniti               23.713000           29.465000     3.000000  227.000000
# Jaguar                 15.467000           42.800000     3.000000  240.000000
# Jeep                   97.717667           20.991667     3.500000  168.333333
# Lexus                  17.807167           44.055000     3.616667  245.833333
# Lincoln                28.544667           41.690000     4.866667  263.333333
# Mercedes-B             13.013889           52.916667     3.422222  232.222222
# Mercury                39.666500           20.748333     3.150000  163.833333
# Mitsubishi             25.842143           22.167429     2.800000  165.142857
# Nissan                 57.090714           22.360714     2.914286  169.000000
# Oldsmobile             29.831500           25.622833     3.450000  190.000000
# Plymouth               16.000250           22.642500     2.475000  166.750000
# Pontiac                61.755667           22.949167     3.433333  185.000000
# Porsche                 4.042667           62.473333     3.166667  272.333333
# Saab                   10.653000           29.610000     2.150000  177.500000
# Saturn                 33.770000           14.271000     2.020000  119.600000
# Subaru                 40.067500           21.395000     2.500000  165.000000
# Toyota                 82.245000           21.982889     2.622222  160.666667
# Volkswagen             34.868667           17.698333     1.966667  120.833333
# Volvo                  12.623333           30.933333     2.300000  182.166667
#
#               Fuel_capacity
# Manufacturer
# Acura             16.400000
# Audi              19.533333
# BMW               17.233333
# Buick             17.750000
# Cadillac          20.800000
# Chevrolet         15.477778
# Chrysler          16.483333
# Dodge             21.581818
# Ford              19.063636
# Honda             17.080000
# Hyundai           14.533333
# Infiniti          18.500000
# Jaguar            18.400000
# Jeep              19.833333
# Lexus             20.533333
# Lincoln           23.000000
# Mercedes-B        18.922222
# Mercury           17.833333
# Mitsubishi        18.285714
# Nissan            18.200000
# Oldsmobile        18.200000
# Plymouth          15.125000
# Pontiac           17.916667
# Porsche           17.000000
# Saab              17.700000
# Saturn            12.500000
# Subaru            16.400000
# Toyota            17.766667
# Volkswagen        14.700000
# Volvo             17.833333

# %% [markdown]
# ##### FILTERING AND AGGREGATION

# %%
df_carSales.mean(numeric_only=True)
# Out:
# Sales_in_thousands     52.998076
# Price_in_thousands     27.390755
# Engine_size             3.060897
# Horsepower            185.948718
# Fuel_capacity          17.951923
# dtype: float64

# %%
def filtering_func(x):
    return x["Sales_in_thousands"].sum() > 52

filtered_df = df_carSales.groupby(["Manufacturer"]).filter(filtering_func)

# %%
# Filtered out values
df_carSales.groupby(["Manufacturer"]).sum()["Sales_in_thousands"].sort_values().head(6)
# Out:
# Manufacturer
# Porsche     12.128
# Jaguar      15.467
# Saab        21.306
# Infiniti    23.713
# Audi        40.557
# BMW         46.505
# Name: Sales_in_thousands, dtype: float64

# %%
# Other method to detect filtered out values

filtered_list = set(filtered_df["Manufacturer"].unique())
original_list = set(df_carSales["Manufacturer"].unique())

original_list - filtered_list

# %%
# Other method again

all_m_idx = pd.Index(df_carSales["Manufacturer"].unique())
filt_m_idx = pd.Index(filtered_df["Manufacturer"].unique())

excluded = all_m_idx.difference(filt_m_idx)
print(excluded.tolist())
# Out:
# ['Audi', 'BMW', 'Infiniti', 'Jaguar', 'Porsche', 'Saab']
