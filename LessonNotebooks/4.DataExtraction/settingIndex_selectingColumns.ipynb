# %%
import pandas as pd
from utilities.reader_tools import GenericCSVReader

df_players = GenericCSVReader.DataframeFromCSV("players_20.csv")

# %%
df_players.head(3)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# 0        170         72   Argentina         FC Barcelona  ...  68+2  66+2
# 1        187         83    Portugal             Juventus  ...  65+3  61+3
# 2        175         68      Brazil  Paris Saint-Germain  ...  66+3  61+3
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# ...

# %% [markdown]
# ##### SET INDEX

# %%
df_players.set_index("short_name", inplace=True)

# %%
df_players.head(3)
# Out:
#                    sofifa_id  \
# short_name
# L. Messi              158023
# Cristiano Ronaldo      20801
# Neymar Jr             190871
#
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
#
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
#
#                    height_cm  weight_kg nationality                 club  \
# short_name
# L. Messi                 170         72   Argentina         FC Barcelona
# Cristiano Ronaldo        187         83    Portugal             Juventus
# ...

# %%
df_players.iloc[:, 0:9]
# Out:
#                    sofifa_id  \
# short_name
# L. Messi              158023
# Cristiano Ronaldo      20801
# Neymar Jr             190871
# J. Oblak              200389
# E. Hazard             183277
# ...                      ...
# Shao Shuai            245006
# Xiao Mingjie          250995
# Zhang Wei             252332
# Wang Haijian          251110
# Pan Ximing            233449
#
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
# ...                                                              ...
# Shao Shuai         https://sofifa.com/player/245006/shuai-shao/20...
# ...

# %%
df_players.loc[:, "sofifa_id":"club"]
# Out:
#                    sofifa_id  \
# short_name
# L. Messi              158023
# Cristiano Ronaldo      20801
# Neymar Jr             190871
# J. Oblak              200389
# E. Hazard             183277
# ...                      ...
# Shao Shuai            245006
# Xiao Mingjie          250995
# Zhang Wei             252332
# Wang Haijian          251110
# Pan Ximing            233449
#
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
# ...                                                              ...
# Shao Shuai         https://sofifa.com/player/245006/shuai-shao/20...
# ...

# %% [markdown]
# ##### FILTER DATASET COLUMNS

# %%
df_players = df_players[["long_name", "age", "dob", "height_cm", "weight_kg", "nationality"]]

# %%
df_players
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality
# short_name
# ...

# %% [markdown]
# ##### LOC - SELECTING WITH A SINGLE VALUE

# %%
df_players.loc["L. Messi"]
# Out:
# long_name      Lionel Andrés Messi Cuccittini
# age                                        32
# dob                                1987-06-24
# height_cm                                 170
# weight_kg                                  72
# nationality                         Argentina
# Name: L. Messi, dtype: object

# %%
df_players.loc["L. Messi", "height_cm"]
# Out:
# np.int64(170)

# %%
df_players.loc["Cristiano Ronaldo", "weight_kg"]
# Out:
# np.int64(83)

# %%
df_players.loc[:, "height_cm"]
# Out:
# short_name
# L. Messi             170
# Cristiano Ronaldo    187
# Neymar Jr            175
# J. Oblak             188
# E. Hazard            175
#                     ...
# Shao Shuai           186
# Xiao Mingjie         177
# Zhang Wei            186
# Wang Haijian         185
# Pan Ximing           182
# Name: height_cm, Length: 18278, dtype: int64

# %%
df_players.loc["L. Messi", :]
# Out:
# long_name      Lionel Andrés Messi Cuccittini
# age                                        32
# dob                                1987-06-24
# height_cm                                 170
# weight_kg                                  72
# nationality                         Argentina
# Name: L. Messi, dtype: object

# %% [markdown]
# ##### SELECTING WITH A LIST OF VALUES

# %%
df_players.loc[["L. Messi", "Cristiano Ronaldo"]]
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
#
#                    height_cm  weight_kg nationality
# short_name
# L. Messi                 170         72   Argentina
# Cristiano Ronaldo        187         83    Portugal

# %%
df_players.loc[["L. Messi", "Cristiano Ronaldo"], "height_cm"]
# Out:
# short_name
# L. Messi             170
# Cristiano Ronaldo    187
# Name: height_cm, dtype: int64

# %%
df_players.loc[["L. Messi"], ["height_cm", "weight_kg"]]
# Out:
#             height_cm  weight_kg
# short_name
# L. Messi          170         72

# %%
df_players.loc[["L. Messi", "Cristiano Ronaldo"], ["height_cm", "weight_kg"]]
# Out:
#                    height_cm  weight_kg
# short_name
# L. Messi                 170         72
# Cristiano Ronaldo        187         83

# %% [markdown]
# ##### RANGE OF DATA WITH SLICE

# %%
players = ["L. Messi", "Cristiano Ronaldo"]
columns = ["age", "height_cm", "weight_kg"]

# %%
df_players.loc[players, "age":"nationality"]
# Out:
#                    age         dob  height_cm  weight_kg nationality
# short_name
# L. Messi            32  1987-06-24        170         72   Argentina
# Cristiano Ronaldo   34  1985-02-05        187         83    Portugal

# %%
df_players.loc[:, columns]
# Out:
#                    age  height_cm  weight_kg
# short_name
# L. Messi            32        170         72
# Cristiano Ronaldo   34        187         83
# Neymar Jr           27        175         68
# J. Oblak            26        188         87
# E. Hazard           28        175         74
# ...                ...        ...        ...
# Shao Shuai          22        186         79
# Xiao Mingjie        22        177         66
# Zhang Wei           19        186         75
# Wang Haijian        18        185         74
# Pan Ximing          26        182         78
#
# [18278 rows x 3 columns]

# %%
# Get top 1 and top 10
df_players.index[:10]
# Out:
# Index(['L. Messi', 'Cristiano Ronaldo', 'Neymar Jr', 'J. Oblak', 'E. Hazard',
#        'K. De Bruyne', 'M. ter Stegen', 'V. van Dijk', 'L. Modrić',
#        'M. Salah'],
#       dtype='object', name='short_name')

# %%
df_players.loc[["L. Messi", "M. Salah"], columns]
# Out:
#             age  height_cm  weight_kg
# short_name
# L. Messi     32        170         72
# M. Salah     27        175         71

# %% [markdown]
# ##### SELECTING WITH CONDITIONS
#
# Both start and stop are included

# %%
# Example
df_players["height_cm"]>180
# Out:
# short_name
# L. Messi             False
# Cristiano Ronaldo     True
# Neymar Jr            False
# J. Oblak              True
# E. Hazard            False
#                      ...
# Shao Shuai            True
# Xiao Mingjie         False
# Zhang Wei             True
# Wang Haijian          True
# Pan Ximing            True
# Name: height_cm, Length: 18278, dtype: bool

# %%
df_players.loc[df_players["height_cm"]>180].index
# Out:
# Index(['Cristiano Ronaldo', 'J. Oblak', 'K. De Bruyne', 'M. ter Stegen',
#        'V. van Dijk', 'K. Koulibaly', 'H. Kane', 'Alisson', 'De Gea',
#        'G. Chiellini',
#        ...
#        'C. Heath', 'S. Cartwright', 'H. Sveijer', 'S. Callan', 'Huang Jiahui',
#        'P. Martin', 'Shao Shuai', 'Zhang Wei', 'Wang Haijian', 'Pan Ximing'],
#       dtype='object', name='short_name', length=9744)

# %%
# Multiple
df_players.loc[(df_players["height_cm"]>180) & (df_players["nationality"]=="Argentina")]
# Out:
#                                   long_name  age         dob  height_cm  \
# short_name
# M. Icardi       Mauro Emanuel Icardi Rivero   26  1993-02-19        181
# G. Higuaín          Gonzalo Gerardo Higuaín   31  1987-12-10        186
# E. Garay             Ezequiel Marcelo Garay   32  1986-10-10        189
# N. Otamendi         Nicolás Hernán Otamendi   31  1988-02-12        183
# G. Rulli                     Gerónimo Rulli   27  1992-05-20        189
# ...                                     ...  ...         ...        ...
# T. Durso                        Tomás Durso   20  1999-02-26        185
# J. Hass                        Joaquín Hass   21  1998-03-27        186
# R. Ferrario                 Rafael Ferrario   19  2000-04-30        186
# L. Finochietto          Leandro Finochietto   22  1997-04-25        186
# N. Forastiero            Nicolás Forastiero   20  1998-07-16        182
#
#                 weight_kg nationality
# short_name
# M. Icardi              75   Argentina
# ...

# %% [markdown]
# ##### SELECTING WITH ILOC

# %%
# Height of Messi

df_players.iloc[0, 3]
# Out:
# np.int64(170)

# %%
# Weight Cristiano

df_players.iloc[1, 4]
# Out:
# np.int64(83)

# %%
df_players.iloc[:, 3]
# Out:
# short_name
# L. Messi             170
# Cristiano Ronaldo    187
# Neymar Jr            175
# J. Oblak             188
# E. Hazard            175
#                     ...
# Shao Shuai           186
# Xiao Mingjie         177
# Zhang Wei            186
# Wang Haijian         185
# Pan Ximing           182
# Name: height_cm, Length: 18278, dtype: int64

# %%
df_players.iloc[0, :]
# Out:
# long_name      Lionel Andrés Messi Cuccittini
# age                                        32
# dob                                1987-06-24
# height_cm                                 170
# weight_kg                                  72
# nationality                         Argentina
# Name: L. Messi, dtype: object

# %% [markdown]
# ##### SELECTING LIST OF VALUES WITH ILOC

# %%
df_players.iloc[[0,1]]
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
#
#                    height_cm  weight_kg nationality
# short_name
# L. Messi                 170         72   Argentina
# Cristiano Ronaldo        187         83    Portugal

# %%
df_players.iloc[[0,1], [3]]
# Out:
#                    height_cm
# short_name
# L. Messi                 170
# Cristiano Ronaldo        187

# %%
df_players.iloc[0, [3, 4]]
# Out:
# height_cm    170
# weight_kg     72
# Name: L. Messi, dtype: object

# %%
df_players.iloc[[0,1], [3, 4]]
# Out:
#                    height_cm  weight_kg
# short_name
# L. Messi                 170         72
# Cristiano Ronaldo        187         83

# %% [markdown]
# ##### SELECTING WITH ILOC AND SLICING
#
# Here, start in included but stop is not

# %%
# players = ["L. Messi", "Cristiano Ronaldo"]
players = [0, 1]

# %%
df_players.iloc[players, 1:6]
# Out:
#                    age         dob  height_cm  weight_kg nationality
# short_name
# L. Messi            32  1987-06-24        170         72   Argentina
# Cristiano Ronaldo   34  1985-02-05        187         83    Portugal

# %%
# columns = ["age", "dob", "height_cm", "weight_kg"]
columns = [1, 2, 3, 4]

# df_players.iloc[[0, 9], columns]
df_players.iloc[0:10, 1:5]
# Out:
#                    age         dob  height_cm  weight_kg
# short_name
# L. Messi            32  1987-06-24        170         72
# Cristiano Ronaldo   34  1985-02-05        187         83
# Neymar Jr           27  1992-02-05        175         68
# J. Oblak            26  1993-01-07        188         87
# E. Hazard           28  1991-01-07        175         74
# K. De Bruyne        28  1991-06-28        181         70
# M. ter Stegen       27  1992-04-30        187         85
# V. van Dijk         27  1991-07-08        193         92
# L. Modrić           33  1985-09-09        172         66
# M. Salah            27  1992-06-15        175         71
