# %% [markdown]
# ##### STRINGS

# %%
mex1 = "lol"
mex2 = "lel"

print(mex1 + " " + mex2)
# Out:
# lol lel

# %%
mex = mex1 + mex2
print(mex)
# Out:
# lollel

# %%
f'lol'
# Out:
# 'lol'

# %%
f'{mex} {mex}'
# Out:
# 'lollel lollel'

# %% [markdown]
# ##### LIST

# %%
funny_words = ["lol" , "lel", "lil", "lal"]
funny_words
# Out:
# ['lol', 'lel', 'lil', 'lal']

# %%
print(funny_words)
# Out:
# ['lol', 'lel']

# %%
funny_words[0]

# If I want to print every item of the list, I have to use the print function and not just the short way
# Out:
# 'lol'

# %%
for i in range(len(funny_words)):
    print(i)
# Out:
# 0
# 1

# %%
funny_words[-2]
# Out:
# 'lol'

# %% [markdown]
# ###### SLICING
#
# list_name[start:stop] -> stop doesn't include itself. Ex: [lol, lel, lil]: if you want to reach lil, stop value will be 3

# %%
sliced = funny_words[1:4]
sliced
# Out:
# ['lel', 'lil', 'lal']

# %%
funny_words[1:]
# Out:
# ['lel', 'lil', 'lal']

# %%
funny_words[:2]
# Out:
# ['lol', 'lel']

# %% [markdown]
# ##### ADDING ELEMENTS

# %%
funny_words.append("lul")

# %%
funny_words
# Out:
# ['lol', 'lel', 'lil', 'lal', 'lul']

# %%
funny_words.insert(0, "easy")

# %%
funny_words
# Out:
# ['easy', 'lol', 'lel', 'lil', 'lal', 'lul']

# %%
funny_words_2 = ["lady", "baby"]

# %%
funny_words + funny_words_2
# Out:
# ['easy', 'lol', 'lel', 'lil', 'lal', 'lul', 'lady', 'baby']

# %% [markdown]
# ##### NESTED LIST
#
# Remember that it won't extract the value and create a whole new list with just value, but each item is a list

# %%
nested = [funny_words, funny_words_2]

# %%
nested
# Out:
# [['easy', 'lol', 'lel', 'lil', 'lal', 'lul'], ['lady', 'baby']]

# %%
nested[0]
# Out:
# ['easy', 'lol', 'lel', 'lil', 'lal', 'lul']

# %% [markdown]
# ##### REMOVING ELEMENTS
