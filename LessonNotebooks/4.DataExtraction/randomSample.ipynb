# %%
import pandas as pd
from utilities.reader_tools import GenericCSVReader

df_players = GenericCSVReader.DataframeFromCSV("players_20.csv", setIndexName="short_name")
df_players.head()
# Out:
#                    sofifa_id  \
# short_name
# L. Messi              158023
# Cristiano Ronaldo      20801
# Neymar Jr             190871
# J. Oblak              200389
# E. Hazard             183277
#
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
#
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# ...

# %%
df_players["nationality"].sample(10, random_state=99)

# Random state blocks the seed
# Out:
# 2158             Mexico
# 15286          China PR
# 3137              Chile
# 15326          Bulgaria
# 11008          Slovakia
# 15866             India
# 821               Italy
# 15038           Croatia
# 14533    Korea Republic
# 17500           Denmark
# Name: nationality, dtype: object

# %%
# We can decide the portion/fraction of the sampling method

df_players["nationality"].sample(frac=0.2)
# Out:
# 16622           England
# 1924              Spain
# 16215           Germany
# 6078              Japan
# 13628             Japan
#               ...
# 2404     Czech Republic
# 1322            Morocco
# 9486            Germany
# 17672           England
# 10882             Spain
# Name: nationality, Length: 3656, dtype: object

# %%
# Upsample rate

df_players.sample(frac = 2, replace=True)
# Out:
#        sofifa_id                                         player_url  \
# 5072      192317  https://sofifa.com/player/192317/jed-steer/20/...
# 9788      214720  https://sofifa.com/player/214720/mauricio-yedr...
# 9336      232573  https://sofifa.com/player/232573/ken-matsubara...
# 9482      235867  https://sofifa.com/player/235867/luca-strizzol...
# 298       180403  https://sofifa.com/player/180403/willian-borge...
# ...          ...                                                ...
# 17585     246923  https://sofifa.com/player/246923/jacob-ramsey/...
# 18125     235611  https://sofifa.com/player/235611/kristoffer-gu...
# 9558      176941  https://sofifa.com/player/176941/adam-rooney/2...
# 987       230431  https://sofifa.com/player/230431/sidney-adrian...
# 13377     246284  https://sofifa.com/player/246284/oscar-gil-reg...
#
#             short_name                     long_name  age         dob  \
# 5072          J. Steer                     Jed Steer   26  1992-09-23
# ...
