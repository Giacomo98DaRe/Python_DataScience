# %% [markdown]
# #### MODULES

# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Giacomo Da Re\\git\\Python_DataScience\\script\\basics'

# %%
os.listdir()
# Out:
# ['functions.ipynb',
#  'hello_world.ipynb',
#  'modules.ipynb',
#  'statements.ipynb',
#  'variables_type.ipynb']

# %%
os.mkdir("trial_folder")

# %%
os.listdir()
# Out:
# ['functions.ipynb',
#  'hello_world.ipynb',
#  'modules.ipynb',
#  'statements.ipynb',
#  'trial_folder',
#  'variables_type.ipynb']
