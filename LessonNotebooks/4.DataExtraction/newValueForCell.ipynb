# %%
import pandas as pd
from utilities.reader_tools import GenericCSVReader

df_players = GenericCSVReader.DataframeFromCSV("players_20.csv")
df_players.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %% [markdown]
# ##### SET VALUE TO ONE CELL

# %%
df_players.set_index("short_name", inplace=True)
df_players = df_players[["long_name", "age", "dob", "height_cm", "weight_kg", "nationality"]]

# %%
df_players.head()
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
#
#                    height_cm  weight_kg nationality
# short_name
# L. Messi                 170         72   Argentina
# Cristiano Ronaldo        187         83    Portugal
# Neymar Jr                175         68      Brazil
# J. Oblak                 188         87    Slovenia
# E. Hazard                175         74     Belgium

# %%
df_players.loc["L. Messi", "height_cm"] = 175
df_players
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality
# short_name
# ...

# %% [markdown]
# ##### SET VALUE TO ENTIRE COLUMN

# %%
df_players.loc[:, "height_cm"] = 190
df_players.loc[:, "height_cm"]
# Out:
# short_name
# L. Messi             190
# Cristiano Ronaldo    190
# Neymar Jr            190
# J. Oblak             190
# E. Hazard            190
#                     ...
# Shao Shuai           190
# Xiao Mingjie         190
# Zhang Wei            190
# Wang Haijian         190
# Pan Ximing           190
# Name: height_cm, Length: 18278, dtype: int64

# %% [markdown]
# ##### SET VALUE TO ENTIRE ROW

# %%
df_players.iloc[-1, :]
# Out:
# long_name             潘喜明
# age                    26
# dob            1993-01-11
# height_cm             190
# weight_kg              78
# nationality      China PR
# Name: Pan Ximing, dtype: object

# %%
import numpy as np

np.nan
df_players.iloc[-1, :] = np.nan
df_players.iloc[-1, :]
# Out:
# long_name      NaN
# age            NaN
# dob            NaN
# height_cm      NaN
# weight_kg      NaN
# nationality    NaN
# Name: Pan Ximing, dtype: object

# %% [markdown]
# ##### SET VALUE TO MULTIPLE CELL

# %%
players = ["L. Messi", "Cristiano Ronaldo"]

df_players.loc[players, "height_cm"]
# Out:
# short_name
# L. Messi             190.0
# Cristiano Ronaldo    190.0
# Name: height_cm, dtype: float64

# %%
df_players.loc[players, "height_cm"] = 175
df_players.loc[players, "height_cm"]
# Out:
# short_name
# L. Messi             175.0
# Cristiano Ronaldo    175.0
# Name: height_cm, dtype: float64

# %% [markdown]
# ##### SET VALUE FOR ROWS MATCHING A CONDITION

# %%
columns = ["long_name", "age", "dob", "height_cm", "weight_kg", "nationality"]

df_players.loc[df_players["height_cm"] > 180, columns]
# Out:
#                                    long_name   age         dob  height_cm  \
# short_name
# Neymar Jr      Neymar da Silva Santos Junior  27.0  1992-02-05      190.0
# J. Oblak                           Jan Oblak  26.0  1993-01-07      190.0
# E. Hazard                        Eden Hazard  28.0  1991-01-07      190.0
# K. De Bruyne                 Kevin De Bruyne  28.0  1991-06-28      190.0
# M. ter Stegen          Marc-André ter Stegen  27.0  1992-04-30      190.0
# ...                                      ...   ...         ...        ...
# P. Martin                        Paul Martin  20.0  1999-01-05      190.0
# Shao Shuai                                邵帅  22.0  1997-03-10      190.0
# Xiao Mingjie                    Mingjie Xiao  22.0  1997-01-01      190.0
# Zhang Wei                                 张威  19.0  2000-05-16      190.0
# Wang Haijian                             汪海健  18.0  2000-08-02      190.0
#
#                weight_kg          nationality
# short_name
# ...

# %%
df_players.loc[df_players["height_cm"] > 180, columns] = 0

# %%
df_players.loc[:, columns]
# Out:
#                                              long_name   age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini  32.0  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  34.0  1985-02-05
# Neymar Jr                                            0   0.0           0
# J. Oblak                                             0   0.0           0
# E. Hazard                                            0   0.0           0
# ...                                                ...   ...         ...
# Shao Shuai                                           0   0.0           0
# Xiao Mingjie                                         0   0.0           0
# Zhang Wei                                            0   0.0           0
# Wang Haijian                                         0   0.0           0
# Pan Ximing                                         NaN   NaN         NaN
#
#                    height_cm  weight_kg nationality
# short_name
# ...
